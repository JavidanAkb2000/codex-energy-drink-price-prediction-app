# %%
import pandas as pd

df = pd.read_pickle("user_input_df.pkl")
df.head()
# Out:
#    preferable_consumption_size  health_concerns  age_group  \
# 0                          1.0              1.0        1.0
#
#    consume_frequency_weekly_encoded  awareness_of_other_brands_encoded  \
# 0                                 1                                  1
#
#    cf_ab_score  zone_encoded  income_levels_encoded  zas_score  bsi  ...  \
# 0          0.5             3                      1          3    1  ...
#
#    current_brand_Newcomer  reasons_for_choosing_brands_Brand Reputation  \
# 0                       0                                             0
#
#    reasons_for_choosing_brands_Price  reasons_for_choosing_brands_Quality  \
# 0                                  0                                    0
#
#    flavor_preference_Traditional  purchase_channel_Retail Store  \
# 0                              0                              0
#
#    packaging_preference_Premium  packaging_preference_Simple  \
# ...
